# %% [markdown]
# # 1
# # This file contains code for analyzing admissions in ped trauma vs non ped trauma facilities

# %%
#2
import pandas as pd
import numpy as np
from time import time
from matplotlib import pyplot as plt
from excel_analysis import b_admission_types

data = b_admission_types()

pediatric_trauma_df = data[0]
non_pediatric_trauma_df = data[1]


plt.title("Pediatric vs Non-Pediatric Trauma Center Admissions Compared, YoY \n", fontdict={"fontsize" : 16})

plt.xlabel("Years since 2013", fontdict={"fontsize" : 14})
plt.ylabel("Average Yearly Admissions\n",  fontdict={"fontsize" : 14})


plt.figure(figsize=[10,10])

    
plt.subplot(2,1,1).set_title( "" )


plt.plot([
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2013 ].EMS_VISITS_NON_URGENT_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2014 ].EMS_VISITS_NON_URGENT_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2015 ].EMS_VISITS_NON_URGENT_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2016 ].EMS_VISITS_NON_URGENT_adm.mean(),
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2017 ].EMS_VISITS_NON_URGENT_adm.mean(),
    ],
    'b.-'
    )

plt.plot([
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2013 ].EMS_VISITS_NON_URGENT_adm.mean(), 
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2014 ].EMS_VISITS_NON_URGENT_adm.mean(), 
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2015 ].EMS_VISITS_NON_URGENT_adm.mean(),
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2016 ].EMS_VISITS_NON_URGENT_adm.mean(),
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2017 ].EMS_VISITS_NON_URGENT_adm.mean(),
    ],
    'r.-'
)

plt.tight_layout()

plt.show()
# Out:
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subtable.dropna(how='all', axis=1, inplace=True)
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subtable.dropna(how='all', axis=0, inplace=True)
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#3
import pandas as pd
import numpy as np
from time import time
from matplotlib import pyplot as plt
from excel_analysis import b_admission_types

data = b_admission_types()

pediatric_trauma_df = data[0]
non_pediatric_trauma_df = data[1]


plt.title("Pediatric vs Non-Pediatric Trauma Center Admissions Compared, YoY \n", fontdict={"fontsize" : 16})
          
plt.xlabel("Years since 2013", fontdict={"fontsize" : 14})
plt.ylabel("Average Yearly Admissions\n",  fontdict={"fontsize" : 14})

plt.figure(figsize=[10,10])

plt.subplot(2,1,1).set_title( "" )


plt.plot([
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2013 ].EMS_VISITS_URGENT_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2014 ].EMS_VISITS_URGENT_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2015 ].EMS_VISITS_URGENT_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2016 ].EMS_VISITS_URGENT_adm.mean(),
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2017 ].EMS_VISITS_URGENT_adm.mean(),
    ],
    'b.-'
    )

plt.plot([
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2013 ].EMS_VISITS_URGENT_adm.mean(), 
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2014 ].EMS_VISITS_URGENT_adm.mean(), 
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2015 ].EMS_VISITS_URGENT_adm.mean(),
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2016 ].EMS_VISITS_URGENT_adm.mean(),
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2017 ].EMS_VISITS_URGENT_adm.mean(),
    ],
    'r.-'
)

plt.tight_layout()

plt.show()
# Out:
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subtable.dropna(how='all', axis=1, inplace=True)
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subtable.dropna(how='all', axis=0, inplace=True)
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#4
import pandas as pd
import numpy as np
from time import time
from matplotlib import pyplot as plt
from excel_analysis import b_admission_types

data = b_admission_types()

pediatric_trauma_df = data[0]
non_pediatric_trauma_df = data[1]

plt.title("Pediatric vs Non-Pediatric Trauma Center Admissions Compared, YoY \n", fontdict={"fontsize" : 16})

plt.xlabel("Years since 2013", fontdict={"fontsize" : 14})
plt.ylabel("Average Yearly Admissions\n",  fontdict={"fontsize" : 14})

plt.figure(figsize=[10,10])
    
plt.subplot(2,1,1).set_title( "" )

plt.plot([
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2013 ].EMS_VISITS_MODERATE_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2014 ].EMS_VISITS_MODERATE_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2015 ].EMS_VISITS_MODERATE_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2016 ].EMS_VISITS_MODERATE_adm.mean(),
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2017 ].EMS_VISITS_MODERATE_adm.mean(),
    ],
    'b.-'
    )

plt.plot([
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2013 ].EMS_VISITS_MODERATE_adm.mean(), 
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2014 ].EMS_VISITS_MODERATE_adm.mean(), 
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2015 ].EMS_VISITS_MODERATE_adm.mean(),
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2016 ].EMS_VISITS_MODERATE_adm.mean(),
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2017 ].EMS_VISITS_MODERATE_adm.mean(),
    ],
    'r.-'
)

plt.tight_layout()

plt.show()
# Out:
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subtable.dropna(how='all', axis=1, inplace=True)
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subtable.dropna(how='all', axis=0, inplace=True)
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#5
import pandas as pd
import numpy as np
from time import time
from matplotlib import pyplot as plt
from excel_analysis import b_admission_types

data = b_admission_types()

pediatric_trauma_df = data[0]

non_pediatric_trauma_df = data[1]

plt.title("Pediatric vs Non-Pediatric Trauma Center Admissions Compared, YoY \n", fontdict={"fontsize" : 16})
          
plt.xlabel("Years since 2013", fontdict={"fontsize" : 14})

plt.ylabel("Average Yearly Admissions\n",  fontdict={"fontsize" : 14})

plt.figure(figsize=[10,10])
    
plt.subplot(2,1,1).set_title( "" )

plt.plot([
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2013 ].EMS_VISITS_SEVERE_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2014 ].EMS_VISITS_SEVERE_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2015 ].EMS_VISITS_SEVERE_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2016 ].EMS_VISITS_SEVERE_adm.mean(),
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2017 ].EMS_VISITS_SEVERE_adm.mean(),
    ],
    'b.-'
    )

plt.plot([
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2013 ].EMS_VISITS_SEVERE_adm.mean(), 
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2014 ].EMS_VISITS_SEVERE_adm.mean(), 
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2015 ].EMS_VISITS_SEVERE_adm.mean(),
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2016 ].EMS_VISITS_SEVERE_adm.mean(),
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2017 ].EMS_VISITS_SEVERE_adm.mean(),
    ],
    'r.-'
)

plt.tight_layout()

plt.show()
# Out:
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subtable.dropna(how='all', axis=1, inplace=True)
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subtable.dropna(how='all', axis=0, inplace=True)
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#6
import pandas as pd
import numpy as np
from time import time
from matplotlib import pyplot as plt
from excel_analysis import b_admission_types

data = b_admission_types()

pediatric_trauma_df = data[0]
non_pediatric_trauma_df = data[1]


plt.title("Pediatric vs Non-Pediatric Trauma Center Admissions Compared, YoY \n", fontdict={"fontsize" : 16})

plt.xlabel("Years since 2013", fontdict={"fontsize" : 14})
plt.ylabel("Average Yearly Admissions\n",  fontdict={"fontsize" : 14})

plt.figure(figsize=[10,10])

plt.subplot(2,1,1).set_title( "" )

plt.plot([
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2013 ].EMS_VISITS_CRITICAL_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2014 ].EMS_VISITS_CRITICAL_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2015 ].EMS_VISITS_CRITICAL_adm.mean(), 
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2016 ].EMS_VISITS_CRITICAL_adm.mean(),
    pediatric_trauma_df[pediatric_trauma_df['year'] == 2017 ].EMS_VISITS_CRITICAL_adm.mean(),
    ],
    'b.-'
    )

plt.plot([
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2013 ].EMS_VISITS_CRITICAL_adm.mean(), 
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2014 ].EMS_VISITS_CRITICAL_adm.mean(), 
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2015 ].EMS_VISITS_CRITICAL_adm.mean(),
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2016 ].EMS_VISITS_CRITICAL_adm.mean(),
    non_pediatric_trauma_df[non_pediatric_trauma_df['year'] == 2017 ].EMS_VISITS_CRITICAL_adm.mean(),
    ],
    'r.-'
)

plt.tight_layout()

plt.show()
# Out:
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subtable.dropna(how='all', axis=1, inplace=True)
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subtable.dropna(how='all', axis=0, inplace=True)
# C:\Users\cadet\Desktop\MedStar TakeHome\excel_analysis.py:375: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
